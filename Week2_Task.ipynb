# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Marco's
test = pd.read_csv('/content/gdrive/MyDrive/DSC180A/Code/data/BNPP_DT_test_with_ages.csv')
val = pd.read_csv('/content/gdrive/MyDrive/DSC180A/Code/data/BNPP_DT_train_with_ages.csv')
train = pd.read_csv('/content/gdrive/MyDrive/DSC180A/Code/data/BNPP_DT_val_with_ages.csv')

# %%
#David's
test = pd.read_csv('/content/gdrive/MyDrive/2022-2023/Fall Qtr/DSC 180A - FA22/Code/data/BNPP_DT_test_with_ages.csv')
val = pd.read_csv('/content/gdrive/MyDrive/2022-2023/Fall Qtr/DSC 180A - FA22/Code/data/BNPP_DT_val_with_ages.csv')
train = pd.read_csv('/content/gdrive/MyDrive/2022-2023/Fall Qtr/DSC 180A - FA22/Code/data/BNPP_DT_train_with_ages.csv')

# %%
test
# Out:
#                    unique_key  bnpp_value_log  BNPP_weight PNA_mask  \
# 0       Defruka_51591102_img1        0.690196            1     None
# 1       Simefol_50638549_img1        0.690196            1     None
# 2      Fufeehou_51416184_img1        0.690196            1     None
# 3       Apororn_51673728_img1        0.690196            1     None
# 4       Gubutho_51305517_img1        0.690196            1     None
# ...                       ...             ...          ...      ...
# 2597    Eslinik_51387018_img1        4.845099            1     None
# 2598   Padaswou_51641346_img1        4.845099            1     None
# 2599    Crifape_51290561_img1        4.845099            1     None
# 2600   Jarubood_51667129_img1        4.845099            1     None
# 2601  Quorsemur_51446703_img1        4.845099            1     None
#
#       PNA_wight_mask  BNP_value  age_at_sampletime
# 0                  1        4.9                 33
# ...

# %%
import h5py
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.array(h5py.File('/content/gdrive/MyDrive/2022-2023/Fall Qtr/DSC 180A - FA22/Code/data/bnpp_frontalonly_1024_10.hdf5')))

# %%
#David's
f = h5py.File('/content/gdrive/MyDrive/2022-2023/Fall Qtr/DSC 180A - FA22/Code/data/bnpp_frontalonly_1024_10.hdf5')

# %%
#Marco's
f = h5py.File('/content/gdrive/MyDrive/DSC180A/Code/data/bnpp_frontalonly_1024_10.hdf5')

# %%
#list(f.keys())
top_key = 'Umefet_51429244_img1'

# %%
test_key = f[top_key][:]
test_key
# Out:
# array([[ 1150.     ,   991.57574,   889.22   , ...,   364.93158,
#           424.56793,   471.     ],
#        [ 1120.3812 ,   915.83234,   860.17346, ...,   357.5568 ,
#           409.25415,   444.5083 ],
#        [ 1032.4056 ,   901.9313 ,   870.71936, ...,   376.0726 ,
#           408.83182,   444.94916],
#        ...,
#        [11184.738  , 10646.195  , 10257.507  , ...,  8331.449  ,
#          8116.2607 ,  8211.855  ],
#        [12149.729  , 11527.023  , 11249.011  , ...,  9267.892  ,
#          9512.013  ,  9446.002  ],
#        [12591.     , 12286.253  , 12206.42   , ..., 10557.234  ,
#         10781.891  , 10711.     ]], dtype=float32)

# %%
test_key.shape
# Out:
# (1024, 1024)

# %%
plt.imshow(test_key)

# %%
from PIL import Image
img = Image.open(test_key)
img.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2846     try:
# -> 2847         fp.seek(0)
#    2848     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-e2bf9e42e34a> in <module>
#       1 from PIL import Image
# ----> 2 img = Image.open(test_key[0])
#       3 img.show()
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2847         fp.seek(0)
#    2848     except (AttributeError, io.UnsupportedOperation):
# -> 2849         fp = io.BytesIO(fp.read())
#    2850         exclusive_fp = True
#    2851
#
# ...
